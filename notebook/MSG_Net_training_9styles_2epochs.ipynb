# %% [markdown]
# # MSG-Net training
#
# Based on: https://github.com/zhanghang1989/PyTorch-Multi-Style-Transfer
#
# Dataset: https://cocodataset.org/#download
#
#     Train - http://images.cocodataset.org/zips/train2014.zip

# %%
# Mount Google Drive for saving intermediate steps and trained model
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# !cp -r "drive/MyDrive/msgnet/images/" "images/"

# %%
# Download dataset
# %mkdir 'dataset/'
# !wget -P "//" "http://images.cocodataset.org/zips/train2014.zip"

# %%
# !cp "/dataset/train2014.zip" "drive/MyDrive/msgnet/dataset/"

# %%
# !unzip "/content/drive/MyDrive/msgnet/dataset/small_train.zip" -d "/dataset/"
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /dataset/val2014/COCO_val2014_000000535608.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000279145.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000243495.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000225791.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000428067.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000059383.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000558498.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000376123.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000191304.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000171062.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000014549.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000121152.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000276596.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000029431.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000036349.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000502055.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000438848.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000364973.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000564166.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000323327.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000338581.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000039656.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000071667.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000376046.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000066394.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000277584.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000383518.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000262466.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000153055.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000155312.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000010440.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000541108.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000202503.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000161308.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000153013.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000089924.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000289842.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000191226.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000157465.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000218224.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000030548.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000347422.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000451501.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000374401.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000274599.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000285235.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000298691.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000319726.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000137822.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000566697.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000280017.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000240436.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000368459.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000107831.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000051976.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000476349.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000252829.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000197716.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000222458.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000277738.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000213649.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000406050.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000301735.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000467752.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000126229.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000397404.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000402405.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000350721.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000187271.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000011699.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000335644.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000262189.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000109313.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000348905.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000269964.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000242679.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000579893.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000198163.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000154230.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000222696.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000261097.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000368242.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000310711.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000282942.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000199203.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000459598.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000083331.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000442019.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000571038.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000019624.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000367582.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000308785.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000248019.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000064121.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000172924.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000236784.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000253940.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000368684.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000429530.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000390689.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000075884.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000243104.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000464006.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000155051.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000075857.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000464317.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000071284.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000228197.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000451463.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000394050.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000249129.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000102741.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000231806.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000052340.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000108541.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000317147.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000300784.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000105480.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000225184.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000348162.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000416787.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000167017.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000157019.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000027756.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000561088.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000209898.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000131453.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000417846.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000215244.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000328397.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000324500.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000116208.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000507893.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000157944.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000398507.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000515540.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000211119.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000233023.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000091402.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000239627.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000235564.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000205300.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000139512.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000459502.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000117719.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000229000.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000170000.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000005860.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000494427.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000030423.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000467951.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000204830.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000432239.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000402992.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000472416.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000414852.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000047367.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000352549.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000552075.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000170232.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000363654.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000047435.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000283717.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000504810.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000517249.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000532580.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000571857.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000257470.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000386553.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000542939.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000252342.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000027433.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000337969.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000168974.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000417193.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000096539.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000442979.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000411674.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000121783.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000156858.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000265208.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000100087.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000528575.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000077396.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000206770.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000549171.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000290078.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000227884.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000024285.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000526394.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000235747.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000022215.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000252911.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000002684.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000075611.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000106193.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000193194.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000184446.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000021903.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000045388.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000063855.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000215062.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000189378.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000237844.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000161569.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000563311.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000154431.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000276146.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000578545.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000161605.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000078426.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000488563.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000375015.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000551669.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000152111.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000242246.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000283005.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000450055.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000081004.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000353180.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000471991.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000007072.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000117201.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000177383.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000369309.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000157046.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000561054.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000175933.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000186977.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000297578.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000316423.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000576015.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000262654.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000022371.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000023272.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000434192.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000046872.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000428375.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000333887.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000365386.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000043613.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000033979.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000451102.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000498392.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000093333.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000566975.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000104327.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000115584.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000531349.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000396692.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000075591.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000236837.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000190291.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000449856.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000173217.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000095707.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000192620.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000328091.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000398377.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000549674.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000053677.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000256903.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000248953.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000269254.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000321008.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000536183.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000007506.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000439710.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000089432.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000063240.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000472795.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000030668.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000315162.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000553780.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000444207.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000358055.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000504125.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000541197.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000320150.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000000761.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000561062.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000581183.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000010684.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000251404.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000107840.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000037470.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000373170.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000465272.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000275219.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000457559.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000111004.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000332845.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000573258.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000555119.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000154711.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000233223.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000184994.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000056129.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000102654.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000255470.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000506471.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000483643.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000013721.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000309678.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000173772.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000070657.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000313398.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000148508.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000281725.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000514376.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000153103.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000197870.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000560566.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000575916.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000040729.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000223857.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000528311.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000459662.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000136285.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000277521.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000451095.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000292905.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000448259.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000550084.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000328372.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000433554.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000144896.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000095078.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000271681.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000148730.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000041899.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000216861.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000137211.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000250311.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000093611.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000408535.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000240751.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000297323.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000537513.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000459428.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000279013.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000394840.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000454326.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000434494.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000087493.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000581332.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000133210.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000430473.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000504635.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000357176.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000464296.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000224862.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000538513.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000409867.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000172649.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000099736.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000204360.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000520478.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000565389.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000058111.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000238258.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000318730.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000209904.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000247438.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000214664.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000561514.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000457249.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000213593.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000409125.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000026670.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000542451.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000052966.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000191738.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000309510.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000531875.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000010217.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000050125.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000568290.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000488374.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000413839.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000287828.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000022158.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000516020.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000377406.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000245793.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000453438.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000450719.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000581253.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000241668.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000485368.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000426309.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000450129.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000454102.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000011742.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000113756.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000274063.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000067959.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000077282.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000143215.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000508822.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000321742.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000346687.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000078093.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000139099.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000342929.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000111117.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000522791.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000363039.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000523780.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000249936.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000404897.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000553869.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000570094.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000121188.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000165919.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000576827.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000045648.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000167356.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000203024.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000057323.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000432293.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000363344.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000052527.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000475678.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000495980.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000187876.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000481159.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000097964.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000208050.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000230150.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000059207.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000389129.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000462324.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000071239.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000148282.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000580418.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000204887.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000292347.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000522175.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000209747.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000500473.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000311883.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000573891.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000281625.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000265596.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000031093.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000482574.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000044723.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000045966.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000012860.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000006688.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000552979.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000078537.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000533408.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000482367.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000275695.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000442993.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000192787.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000299838.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000579240.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000529698.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000164759.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000476175.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000548879.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000094865.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000354121.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000483358.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000353982.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000428336.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000278843.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000419378.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000439007.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000262003.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000196919.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000342933.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000513417.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000428140.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000154701.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000510734.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000005600.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000208740.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000212346.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000063661.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000270593.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000482160.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000565954.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000455483.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000484531.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000166563.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000541132.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000445972.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000116951.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000288076.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000365752.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000063521.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000560361.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000293057.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000460347.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000255950.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000238866.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000376236.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000512657.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000487482.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000052413.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000155478.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000470070.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000065270.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000505663.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000021394.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000060049.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000449432.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000552942.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000208406.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000070332.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000143927.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000527374.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000338941.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000191613.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000434142.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000572347.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000109827.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000355450.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000050054.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000317565.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000476415.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000083059.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000155571.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000128516.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000467696.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000001668.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000128978.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000181888.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000069906.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000275058.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000056400.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000531178.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000211141.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000115006.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000225130.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000126974.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000223426.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000356302.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000177535.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000064842.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000036124.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000207670.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000516372.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000355819.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000141524.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000327917.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000567205.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000413538.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000050926.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000124232.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000209788.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000124210.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000530052.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000208107.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000398554.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000018193.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000318671.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000555050.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000408501.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000521419.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000234660.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000492758.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000330790.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000515577.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000388409.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000377231.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000292931.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000577976.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000442480.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000320026.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000460944.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000455343.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000209147.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000066231.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000405547.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000379441.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000519853.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000130651.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000301282.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000511050.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000075001.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000416818.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000572802.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000558114.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000249884.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000294209.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000388398.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000485580.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000402858.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000204749.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000111259.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000136173.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000462289.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000294134.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000522727.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000141172.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000335833.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000573391.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000410496.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000277971.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000228604.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000109819.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000214274.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000313888.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000247918.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000030407.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000458781.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000372246.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000554273.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000135797.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000443537.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000245320.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000274800.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000346259.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000104906.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000107375.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000053229.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000579337.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000032193.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000357824.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000541123.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000578467.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000149890.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000241677.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000247259.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000068352.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000560011.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000009420.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000295768.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000450404.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000189740.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000278601.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000289899.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000475413.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000503311.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000527447.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000216894.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000509514.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000360064.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000432276.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000311531.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000340503.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000053958.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000084312.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000367689.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000008493.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000005673.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000079657.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000440358.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000359838.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000384651.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000129548.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000213156.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000145009.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000040011.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000128939.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000330091.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000290179.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000501080.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000217228.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000292033.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000334466.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000201163.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000415672.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000329568.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000291412.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000403584.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000352027.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000520933.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000140542.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000281429.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000299448.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000323751.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000192403.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000042215.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000093735.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000327983.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000573179.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000546463.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000077178.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000381551.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000120584.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000035760.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000505492.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000432120.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000426275.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000461655.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000362712.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000374858.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000204232.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000041773.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000229207.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000255665.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000569862.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000483656.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000044524.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000019559.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000550471.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000210228.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000130401.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000237324.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000229599.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000419223.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000146315.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000473728.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000463599.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000105751.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000485148.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000270244.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000246308.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000297425.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000344439.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000022874.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000214703.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000352206.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000490643.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000447328.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000327315.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000014038.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000126340.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000295138.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000433676.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000246064.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000147132.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000118124.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000515214.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000360762.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000376393.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000061805.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000066064.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000244019.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000268215.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000365626.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000390184.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000502136.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000386035.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000230795.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000244455.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000434129.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000248767.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000161227.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000559707.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000441686.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000032724.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000329319.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000208208.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000418961.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000055013.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000223740.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000180739.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000475641.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000133078.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000518729.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000212675.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000042102.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000105918.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000445567.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000218189.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000343466.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000549410.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000054335.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000193680.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000324774.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000130240.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000212257.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000386841.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000031164.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000210394.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000067805.jpg
# ...
#  extracting: /dataset/val2014/COCO_val2014_000000016318.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000045603.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000012748.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000119581.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000103667.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000114164.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000251857.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000397089.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000027585.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000047651.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000109291.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000434657.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000467107.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000055077.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000529626.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000065306.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000279265.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000173471.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000298493.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000401991.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000236432.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000100245.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000456833.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000208516.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000375980.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000236338.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000385115.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000069138.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000362483.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000110630.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000206757.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000468953.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000479613.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000270609.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000044877.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000279305.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000229553.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000170393.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000083065.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000229358.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000046269.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000394892.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000448861.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000187329.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000429386.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000527363.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000400596.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000224974.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000341128.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000134034.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000263612.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000476282.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000542211.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000383322.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000165202.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000563175.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000050756.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000115379.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000141517.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000404618.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000218026.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000253988.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000265151.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000269419.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000503490.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000567013.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000072000.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000546934.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000364299.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000170191.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000469242.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000138556.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000295006.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000502275.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000103163.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000573066.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000323442.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000305195.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000018575.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000249825.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000209431.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000076334.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000129855.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000251094.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000030595.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000539423.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000266727.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000469877.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000156246.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000222866.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000366295.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000030353.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000078465.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000099182.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000423396.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000211618.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000150301.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000537692.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000078488.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000257053.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000489799.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000235857.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000497351.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000133515.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000314426.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000283131.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000322511.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000479078.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000238598.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000046405.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000198724.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000279838.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000507739.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000064859.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000393423.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000405205.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000442040.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000221272.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000565273.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000158849.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000448205.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000243344.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000393267.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000401018.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000137619.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000367804.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000206260.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000446850.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000300989.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000449180.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000201727.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000182469.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000243852.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000409030.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000294776.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000136941.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000204098.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000182050.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000215596.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000228214.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000406071.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000397459.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000203509.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000293300.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000142934.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000523297.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000485290.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000484425.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000120535.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000180584.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000313228.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000486580.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000563762.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000099481.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000213599.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000062060.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000283028.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000366711.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000308388.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000364133.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000544237.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000199989.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000290282.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000542042.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000274014.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000318022.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000207437.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000461885.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000562708.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000272015.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000541744.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000183786.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000577853.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000181488.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000330079.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000107963.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000327433.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000485343.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000435444.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000324584.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000536235.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000226848.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000270316.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000165831.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000240301.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000144003.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000308167.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000269918.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000400915.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000270677.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000506803.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000094174.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000005443.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000157084.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000437895.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000078499.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000219269.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000117028.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000073470.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000316499.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000351554.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000164779.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000154139.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000258911.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000041373.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000466005.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000066523.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000332877.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000514294.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000070945.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000199927.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000206751.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000036077.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000201045.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000079490.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000079566.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000086988.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000560266.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000254834.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000190783.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000524575.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000433156.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000532620.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000533171.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000074462.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000386584.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000575625.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000000599.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000316123.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000442206.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000411665.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000112698.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000395462.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000368663.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000399049.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000479939.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000132860.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000281315.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000014526.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000154892.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000535313.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000008483.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000259087.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000030667.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000132288.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000155617.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000049682.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000382438.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000488693.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000324492.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000543836.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000551804.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000045516.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000347233.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000154202.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000038210.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000113113.jpg
#  extracting: /dataset/val2014/COCO_val2014_000000441814.jpg

# %%
# %mkdir "models/"

# %%
import os
import sys
import time
import numpy as np
from tqdm import tqdm, trange

import torch
from torch.optim import Adam
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader

import torchvision
from torchvision import datasets
from torchvision import transforms

from PIL import Image


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")
# Out:
# Device: cuda

# %%
class GramMatrix(nn.Module):
    def forward(self, y):
        (b, ch, h, w) = y.size()
        features = y.view(b, ch, w * h)
        features_t = features.transpose(1, 2)
        gram = features.bmm(features_t) / (ch * h * w)
        return gram


class Bottleneck(nn.Module):
    """ Pre-activation residual block
    Identity Mapping in Deep Residual Networks
    ref https://arxiv.org/abs/1603.05027
    """
    def __init__(self, inplanes, planes, stride=1, downsample=None, norm_layer=nn.BatchNorm2d):
        super(Bottleneck, self).__init__()
        self.expansion = 4
        self.downsample = downsample
        if self.downsample is not None:
            self.residual_layer = nn.Conv2d(inplanes, planes * self.expansion,
                                                        kernel_size=1, stride=stride)
        conv_block = []
        conv_block += [ norm_layer(inplanes),
                        nn.ReLU(inplace=True),
                        nn.Conv2d(inplanes, planes, kernel_size=1, stride=1)]
        conv_block += [ norm_layer(planes),
                        nn.ReLU(inplace=True),
                        ConvLayer(planes, planes, kernel_size=3, stride=stride)]
        conv_block += [ norm_layer(planes),
                        nn.ReLU(inplace=True),
                        nn.Conv2d(planes, planes * self.expansion, kernel_size=1, stride=1)]
        self.conv_block = nn.Sequential(*conv_block)
        
    def forward(self, x):
        if self.downsample is not None:
            residual = self.residual_layer(x)
        else:
            residual = x
        return residual + self.conv_block(x)


class UpBottleneck(nn.Module):
    """ Up-sample residual block (from MSG-Net paper)
    Enables passing identity all the way through the generator
    ref https://arxiv.org/abs/1703.06953
    """
    def __init__(self, inplanes, planes, stride=2, norm_layer=nn.BatchNorm2d):
        super(UpBottleneck, self).__init__()
        self.expansion = 4
        self.residual_layer = UpsampleConvLayer(inplanes, planes * self.expansion,
                                    kernel_size=1, stride=1, upsample=stride)
        conv_block = []
        conv_block += [ norm_layer(inplanes),
                        nn.ReLU(inplace=True),
                        nn.Conv2d(inplanes, planes, kernel_size=1, stride=1)]
        conv_block += [ norm_layer(planes),
                        nn.ReLU(inplace=True),
                        UpsampleConvLayer(planes, planes, kernel_size=3, stride=1, upsample=stride)]
        conv_block += [ norm_layer(planes),
                        nn.ReLU(inplace=True),
                        nn.Conv2d(planes, planes * self.expansion, kernel_size=1, stride=1)]
        self.conv_block = nn.Sequential(*conv_block)

    def forward(self, x):
        return  self.residual_layer(x) + self.conv_block(x)


class ConvLayer(torch.nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, stride):
        super(ConvLayer, self).__init__()
        reflection_padding = int(np.floor(kernel_size / 2))
        self.reflection_pad = nn.ReflectionPad2d(reflection_padding)
        self.conv2d = nn.Conv2d(in_channels, out_channels, kernel_size, stride)

    def forward(self, x):
        out = self.reflection_pad(x)
        out = self.conv2d(out)
        return out

class UpsampleConvLayer(torch.nn.Module):
    """UpsampleConvLayer
    Upsamples the input and then does a convolution. This method gives better results
    compared to ConvTranspose2d.
    ref: http://distill.pub/2016/deconv-checkerboard/
    """

    def __init__(self, in_channels, out_channels, kernel_size, stride, upsample=None):
        super(UpsampleConvLayer, self).__init__()
        self.upsample = upsample
        if upsample:
            self.upsample_layer = torch.nn.Upsample(scale_factor=upsample)
        self.reflection_padding = int(np.floor(kernel_size / 2))
        if self.reflection_padding != 0:
            self.reflection_pad = nn.ReflectionPad2d(self.reflection_padding)
        self.conv2d = nn.Conv2d(in_channels, out_channels, kernel_size, stride)

    def forward(self, x):
        if self.upsample:
            x = self.upsample_layer(x)
        if self.reflection_padding != 0:
            x = self.reflection_pad(x)
        out = self.conv2d(x)
        return out


class Inspiration(nn.Module):
    """ Inspiration Layer (from MSG-Net paper)
    tuning the featuremap with target Gram Matrix
    ref https://arxiv.org/abs/1703.06953
    """
    def __init__(self, C, B=1):
        super(Inspiration, self).__init__()
        # B is equal to 1 or input mini_batch
        self.weight = nn.Parameter(torch.Tensor(1,C,C), requires_grad=True)
        # non-parameter buffer
        self.G = Variable(torch.Tensor(B,C,C), requires_grad=True)
        self.C = C
        self.reset_parameters()

    def reset_parameters(self):
        self.weight.data.uniform_(0.0, 0.02)

    def setTarget(self, target):
        self.G = target

    def forward(self, X):
        # input X is a 3D feature map
        self.P = torch.bmm(self.weight.expand_as(self.G),self.G)
        return torch.bmm(self.P.transpose(1,2).expand(X.size(0), self.C, self.C), \
                         X.view(X.size(0),X.size(1),-1)).view_as(X)

    def __repr__(self):
        return self.__class__.__name__ + '(' + 'N x ' + str(self.C) + ')'


class Vgg16(torch.nn.Module):
    def __init__(self):
        super(Vgg16, self).__init__()
        self.conv1_1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1)
        self.conv1_2 = nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1)

        self.conv2_1 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
        self.conv2_2 = nn.Conv2d(128, 128, kernel_size=3, stride=1, padding=1)

        self.conv3_1 = nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1)
        self.conv3_2 = nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=1)
        self.conv3_3 = nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=1)

        self.conv4_1 = nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1)
        self.conv4_2 = nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1)
        self.conv4_3 = nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1)

        self.conv5_1 = nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1)
        self.conv5_2 = nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1)
        self.conv5_3 = nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1)

    def forward(self, X):
        h = F.relu(self.conv1_1(X))
        h = F.relu(self.conv1_2(h))
        relu1_2 = h
        h = F.max_pool2d(h, kernel_size=2, stride=2)

        h = F.relu(self.conv2_1(h))
        h = F.relu(self.conv2_2(h))
        relu2_2 = h
        h = F.max_pool2d(h, kernel_size=2, stride=2)

        h = F.relu(self.conv3_1(h))
        h = F.relu(self.conv3_2(h))
        h = F.relu(self.conv3_3(h))
        relu3_3 = h
        h = F.max_pool2d(h, kernel_size=2, stride=2)

        h = F.relu(self.conv4_1(h))
        h = F.relu(self.conv4_2(h))
        h = F.relu(self.conv4_3(h))
        relu4_3 = h

        return [relu1_2, relu2_2, relu3_3, relu4_3]        


class Net(nn.Module):
    def __init__(self, input_nc=3, output_nc=3, ngf=64, norm_layer=nn.InstanceNorm2d, n_blocks=6, gpu_ids=[]):
        super(Net, self).__init__()
        self.gpu_ids = gpu_ids
        self.gram = GramMatrix()

        block = Bottleneck
        upblock = UpBottleneck
        expansion = 4

        model1 = []
        model1 += [ConvLayer(input_nc, 64, kernel_size=7, stride=1),
                            norm_layer(64),
                            nn.ReLU(inplace=True),
                            block(64, 32, 2, 1, norm_layer),
                            block(32*expansion, ngf, 2, 1, norm_layer)]
        self.model1 = nn.Sequential(*model1)

        model = []
        self.ins = Inspiration(ngf*expansion)
        model += [self.model1]
        model += [self.ins]    

        for i in range(n_blocks):
            model += [block(ngf*expansion, ngf, 1, None, norm_layer)]
        
        model += [upblock(ngf*expansion, 32, 2, norm_layer),
                            upblock(32*expansion, 16, 2, norm_layer),
                            norm_layer(16*expansion),
                            nn.ReLU(inplace=True),
                            ConvLayer(16*expansion, output_nc, kernel_size=7, stride=1)]

        self.model = nn.Sequential(*model)

    def setTarget(self, Xs):
        F = self.model1(Xs)
        G = self.gram(F)
        self.ins.setTarget(G)

    def forward(self, input):
        return self.model(input)

# %%
#@title Utils

def tensor_load_rgbimage(filename, size=None, scale=None, keep_asp=False):
    img = Image.open(filename).convert('RGB')
    if size is not None:
        if keep_asp:
            size2 = int(size * 1.0 / img.size[0] * img.size[1])
            img = img.resize((size, size2), Image.ANTIALIAS)
        else:
            img = img.resize((size, size), Image.ANTIALIAS)

    elif scale is not None:
        img = img.resize((int(img.size[0] / scale), int(img.size[1] / scale)), Image.ANTIALIAS)
    img = np.array(img).transpose(2, 0, 1)
    img = torch.from_numpy(img).float()
    return img


def subtract_imagenet_mean_batch(batch):
    """Subtract ImageNet mean pixel-wise from a BGR image."""
    tensortype = type(batch.data)
    mean = tensortype(batch.data.size())
    mean[:, 0, :, :] = 103.939
    mean[:, 1, :, :] = 116.779
    mean[:, 2, :, :] = 123.680
    mean = mean.to(device)
    return batch - Variable(mean)


def gram_matrix(y):
    (b, ch, h, w) = y.size()
    features = y.view(b, ch, w * h)
    features_t = features.transpose(1, 2)
    gram = features.bmm(features_t) / (ch * h * w)
    return gram


def preprocess_batch(batch):
    batch = batch.transpose(0, 1)
    (r, g, b) = torch.chunk(batch, 3)
    batch = torch.cat((b, g, r))
    batch = batch.transpose(0, 1)
    return batch


# def init_vgg16(model_folder):
#     """load the vgg16 model feature"""
#     if not os.path.exists(os.path.join(model_folder, 'vgg16.weight')):
#         if not os.path.exists(os.path.join(model_folder, 'vgg16.t7')):
#             os.system(
#                 'wget http://cs.stanford.edu/people/jcjohns/fast-neural-style/models/vgg16.t7 -O ' + os.path.join(model_folder, 'vgg16.t7'))
#         vgglua = load_lua(os.path.join('/content/' + model_folder, 'vgg16.t7'))
#         vgg = Vgg16()
#         print(type(vgglua))
#         for (src, dst) in zip(vgglua.parameters()[0], vgg.parameters()):
#             dst.data[:] = src
#         torch.save(vgg.state_dict(), os.path.join('/content/' + model_folder, 'vgg16.weight'))


def init_vgg16(vgg16):
    torch_vgg16 = torchvision.models.vgg16( \
        weights=torchvision.models.VGG16_Weights.IMAGENET1K_FEATURES).features
    vgg16_list = list(vgg16.children())
    torch_vgg16_list = [x for x in list(vgg16.children()) if isinstance(x, nn.Conv2d)]

    for v, t in zip(vgg16_list, torch_vgg16_list):
        v.load_state_dict(t.state_dict())


class StyleLoader():
    def __init__(self, style_folder, style_size):
        self.folder = style_folder
        self.style_size = style_size
        self.files = os.listdir(style_folder)
    
    def get(self, i):
        idx = i%len(self.files)
        filepath = os.path.join(self.folder, self.files[idx])
        style = tensor_load_rgbimage(filepath, self.style_size)    
        style = style.unsqueeze(0)
        style = preprocess_batch(style)
        style = style.to(device)
        style_v = Variable(style, requires_grad=False)
        return style_v

    def size(self):
        return len(self.files)

# %%
def train():
    seed = 42
    np.random.seed(seed)
    if device.type == 'cuda':
        torch.cuda.manual_seed(seed)
    else:
        torch.manual_seed(seed)

    image_size = 256
    dataset_path = '/dataset/'
    batch_size = 4

    transform = transforms.Compose([transforms.Resize(image_size),
                                    transforms.CenterCrop(image_size),
                                    transforms.ToTensor(),
                                    transforms.Lambda(lambda x: x.mul(255))])
    train_dataset = datasets.ImageFolder(dataset_path, transform)
    train_loader = DataLoader(train_dataset, batch_size=4, num_workers=2)

    style_model = Net(ngf=128)

    # if args.resume is not None:
    #     print('Resuming, initializing using weight from {}.'.format(args.resume))
    #     style_model.load_state_dict(torch.load(args.resume))

    # print(style_model)
    optimizer = Adam(style_model.parameters(), lr=1e-3)
    mse_loss = torch.nn.MSELoss()

    vgg = Vgg16()
    # vgg_model_dir = 'models/'
    # init_vgg16(vgg_model_dir)
    # vgg.load_state_dict(torch.load(os.path.join(vgg_model_dir, "vgg16.weight")))
    init_vgg16(vgg)

    # if device == 'cuda':
    #     style_model.cuda()
    #     vgg.cuda()
    style_model = style_model.to(device)
    vgg = vgg.to(device)


    style_folder = "images/9styles/"
    style_size = 512
    style_loader = StyleLoader(style_folder, style_size)

    epochs = 2
    tbar = trange(epochs)
    for e in tbar:
        style_model.train()
        agg_content_loss = 0.
        agg_style_loss = 0.
        count = 0
        for batch_id, (x, _) in enumerate(train_loader):
            n_batch = len(x)
            count += n_batch
            optimizer.zero_grad()
            x = Variable(preprocess_batch(x))
            x = x.to(device)

            style_v = style_loader.get(batch_id)
            style_model.setTarget(style_v)

            style_v = subtract_imagenet_mean_batch(style_v)
            features_style = vgg(style_v)
            gram_style = [gram_matrix(y) for y in features_style]

            y = style_model(x)
            xc = Variable(x.data.clone())

            y = subtract_imagenet_mean_batch(y)
            xc = subtract_imagenet_mean_batch(xc)

            features_y = vgg(y)
            features_xc = vgg(xc)

            f_xc_c = Variable(features_xc[1].data, requires_grad=False)

            content_weight = 1
            content_loss = content_weight * mse_loss(features_y[1], f_xc_c)

            style_weight = 5
            style_loss = 0.
            for m in range(len(features_y)):
                gram_y = gram_matrix(features_y[m])
                gram_s = Variable(gram_style[m].data, requires_grad=False).repeat(batch_size, 1, 1, 1)
                style_loss += style_weight * mse_loss(gram_y, gram_s[:n_batch, :, :])

            total_loss = content_loss + style_loss
            total_loss.backward()
            optimizer.step()

            agg_content_loss += content_loss.item()
            agg_style_loss += style_loss.item()

            log_interval = 500
            if (batch_id + 1) % log_interval == 0:
                mesg = "{}\tEpoch {}:\t[{}/{}]\tcontent: {:.6f}\tstyle: {:.6f}\ttotal: {:.6f}".format(
                    time.ctime(), e + 1, count, len(train_dataset),
                                agg_content_loss / (batch_id + 1),
                                agg_style_loss / (batch_id + 1),
                                (agg_content_loss + agg_style_loss) / (batch_id + 1)
                )
                tbar.set_description(mesg)

            
            if (batch_id + 1) % (4 * log_interval) == 0:
                # save model
                style_model.eval()
                # style_model.cpu()
                save_model_filename = "Epoch_" + str(e) + "iters_" + str(count) + "_" + \
                    str(time.ctime()).replace(' ', '_') + "_" + str(
                    content_weight) + "_" + str(style_weight) + ".model"
                save_model_dir = "/content/drive/MyDrive/msgnet/models/"
                # %mkdir "/content/drive/MyDrive/msgnet/models/"
                save_model_path = os.path.join(save_model_dir, save_model_filename)
                torch.save(style_model.state_dict(), save_model_path)
                style_model.train()
                # style_model.cuda()
                tbar.set_description("\nCheckpoint, trained model saved at", save_model_path)

    # save model
    style_model.eval()
    # style_model.cpu()
    save_model_filename = "Final_epoch_" + str(epochs) + "_" + \
        str(time.ctime()).replace(' ', '_') + "_" + str(
        content_weight) + "_" + str(style_weight) + ".model"
    save_model_path = os.path.join(save_model_dir, save_model_filename)
    torch.save(style_model.state_dict(), save_model_path)

    print("\nDone, trained model saved at", save_model_path)

# %%
#@title train

train()
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.8/dist-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4, 1, 64, 64])) that is different to the input size (torch.Size([4, 64, 64])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4, 1, 128, 128])) that is different to the input size (torch.Size([4, 128, 128])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4, 1, 256, 256])) that is different to the input size (torch.Size([4, 256, 256])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4, 1, 512, 512])) that is different to the input size (torch.Size([4, 512, 512])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Thu Jan 26 21:57:44 2023	Epoch 1:	[8000/40504]	content: 1.818218	style: 5.272243	total: 7.090462:   0%|          | 0/2 [17:47<?, ?it/s]
# Thu Jan 26 22:15:34 2023	Epoch 1:	[16000/40504]	content: 1.751497	style: 3.410808	total: 5.162305:   0%|          | 0/2 [35:37<?, ?it/s]
# mkdir: cannot create directory ‘save_model_dir’: File exists
# Thu Jan 26 22:33:24 2023	Epoch 1:	[24000/40504]	content: 1.676306	style: 2.652489	total: 4.328795:   0%|          | 0/2 [53:28<?, ?it/s]
# mkdir: cannot create directory ‘save_model_dir’: File exists
# Thu Jan 26 22:51:13 2023	Epoch 1:	[32000/40504]	content: 1.630302	style: 2.181413	total: 3.811715:   0%|          | 0/2 [1:11:16<?, ?it/s]
# mkdir: cannot create directory ‘save_model_dir’: File exists
# Thu Jan 26 23:09:01 2023	Epoch 1:	[40000/40504]	content: 1.593472	style: 1.863343	total: 3.456815:   0%|          | 0/2 [1:29:04<?, ?it/s]
# mkdir: cannot create directory ‘save_model_dir’: File exists
# Checkpoint, trained model saved at:   0%|          | 0/2 [1:29:05<?, ?it/s]
# Thu Jan 26 23:27:57 2023	Epoch 2:	[8000/40504]	content: 1.370187	style: 0.346426	total: 1.716613:  50%|█████     | 1/2 [1:48:01<1:30:12, 5412.52s/it]
# mkdir: cannot create directory ‘save_model_dir’: File exists
# Thu Jan 26 23:45:45 2023	Epoch 2:	[16000/40504]	content: 1.367630	style: 0.366309	total: 1.733939:  50%|█████     | 1/2 [2:05:49<1:30:12, 5412.52s/it]
# mkdir: cannot create directory ‘save_model_dir’: File exists
# Fri Jan 27 00:03:35 2023	Epoch 2:	[24000/40504]	content: 1.350808	style: 0.351876	total: 1.702685:  50%|█████     | 1/2 [2:23:39<1:30:12, 5412.52s/it]
# mkdir: cannot create directory ‘save_model_dir’: File exists
# Fri Jan 27 00:21:24 2023	Epoch 2:	[32000/40504]	content: 1.332147	style: 0.325363	total: 1.657510:  50%|█████     | 1/2 [2:41:28<1:30:12, 5412.52s/it]
# mkdir: cannot create directory ‘save_model_dir’: File exists
# Fri Jan 27 00:39:11 2023	Epoch 2:	[40000/40504]	content: 1.320393	style: 0.329577	total: 1.649970:  50%|█████     | 1/2 [2:59:15<1:30:12, 5412.52s/it]
# mkdir: cannot create directory ‘save_model_dir’: File exists
# Checkpoint, trained model saved at:  50%|█████     | 1/2 [2:59:15<1:30:12, 5412.52s/it]
# Checkpoint, trained model saved at: 100%|██████████| 2/2 [3:00:22<00:00, 5411.23s/it]
# Checkpoint, trained model saved at: 100%|██████████| 2/2 [3:00:22<00:00, 5411.43s/it]
# Done, trained model saved at /content/drive/MyDrive/msgnet/models/Final_epoch_2_Fri_Jan_27_00:40:19_2023_1_5.model

# %%
content_path = '/content/images/content/venice-boat.jpg'
display(Image.open(content_path).resize((500, 300)))
# Out:
# <PIL.Image.Image image mode=RGB size=500x300 at 0x7F738164DBE0>

# %%
style_path = '/content/images/9styles/candy.jpg'
display(Image.open(style_path).resize((300, 300)))
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F7388207C40>

# %%
content_image = tensor_load_rgbimage(content_path, size=512,
                                     keep_asp=True).unsqueeze(0)
style = tensor_load_rgbimage(style_path, size=512).unsqueeze(0)
style = preprocess_batch(style)

# %%
style_model = Net(ngf=128)
model_dict = torch.load('/content/drive/MyDrive/msgnet/models/my.model')
model_dict_clone = model_dict.copy()
for key, value in model_dict_clone.items():
    if key.endswith(('running_mean', 'running_var')):
        del model_dict[key]
style_model.load_state_dict(model_dict, False)
# Out:
# <All keys matched successfully>

# %%
def tensor_save_rgbimage(tensor, filename, cuda=False):
    if cuda:
        img = tensor.clone().cpu().clamp(0, 255).numpy()
    else:
        img = tensor.clone().clamp(0, 255).numpy()
    img = img.transpose(1, 2, 0).astype('uint8')
    img = Image.fromarray(img)
    img.save(filename)

def tensor_save_bgrimage(tensor, filename, cuda=False):
    (b, g, r) = torch.chunk(tensor, 3)
    tensor = torch.cat((r, g, b))
    tensor_save_rgbimage(tensor, filename, cuda)

# %%
style_v = Variable(style)
content_image = Variable(preprocess_batch(content_image))
style_model.setTarget(style_v)
output = style_model(content_image)
tensor_save_bgrimage(output.data[0], 'output.jpg', False)

# %%
display(Image.open('output.jpg'))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x320 at 0x7F73816C3250>

# %% [markdown]
# Result from the original article
#
#     https://github.com/zhanghang1989/PyTorch-Multi-Style-Transfer/blob/master/msgnet.ipynb
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Such a difference might be because I trained my model on a smaller dataset and with only with 2 epochs (against 4 as was suggested - https://hangzhang.org/PyTorch-Encoding/tutorials/style.html#train-your-own-msg-net-model). Also, I loaded the Vgg16 model with standard weights from the pytorchvision package, and the author loaded some another one (pretrained lua-model of Vgg16). And of course it cannot be ruled out that I made mistakes when adapting the author's code)

# %%
from datetime import datetime

def inference(content_path, style_path):
    display(Image.open(content_path).resize((500, 300)))
    print()
    display(Image.open(style_path).resize((300, 300)))
    print()
    content_image = tensor_load_rgbimage(content_path, size=512,
                                     keep_asp=True).unsqueeze(0)
    style = tensor_load_rgbimage(style_path, size=512).unsqueeze(0)
    style = preprocess_batch(style)
    
    style_v = Variable(style)
    content_image = Variable(preprocess_batch(content_image))
    style_model.setTarget(style_v)
    output = style_model(content_image)
    output_path = f'output + {datetime.now()}.jpg'
    tensor_save_bgrimage(output.data[0], output_path, False)
    display(Image.open(output_path))

# %%
inference('/content/images/content/venice-boat.jpg', '/content/images/9styles/starry_night.jpg')
# Out:
# <PIL.Image.Image image mode=RGB size=500x300 at 0x7F738164D6D0>
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F73815F7E80>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x320 at 0x7F7410E9FDC0>

# %%
inference('/content/images/content/noise.jpg', '/content/images/9styles/composition_vii.jpg')
# Out:
# <PIL.Image.Image image mode=RGB size=500x300 at 0x7F73814B50A0>
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F738C5B4850>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x344 at 0x7F738164D340>

# %%
inference('/content/images/content/shenyang.jpg', '/content/images/9styles/udnie.jpg')
# Out:
# <PIL.Image.Image image mode=RGB size=500x300 at 0x7F73815F72E0>
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F738164D280>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x340 at 0x7F7381549370>

# %%
inference('/content/images/content/shenyang3.jpg', '/content/images/9styles/the_scream.jpg')
# Out:
# <PIL.Image.Image image mode=RGB size=500x300 at 0x7F738164D5B0>
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F73815F7700>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x396 at 0x7F73815F7E80>
